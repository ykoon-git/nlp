# %%
import pandas as pd
import numpy as np

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch

torch.cuda.is_available()
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 4070 Ti'

# %%
df = pd.read_csv("ClientList.csv")
df.head()
# Out:
#    Internet access state             Device Type           Client Name  \
# 0  Allow Internet access         WESTERN DIGITAL             WDMyCloud
# 1  Allow Internet access  Loading manufacturer..           BapuriWatch
# 2  Allow Internet access              Apple Inc.            YK-MacBook
# 3  Allow Internet access  Loading manufacturer..  Philips Wiz - Room 1
# 4  Allow Internet access                     WiZ  Philips Wiz - Room 2
#
#   Client IP address       IP Method Clients MAC Address Interface Tx Rate  \
# 0     192.168.1.150  MAC-IP Binding   00:90:A9:D5:D7:59     Wired       -
# 1      192.168.1.20    Automatic IP   2C:7C:F2:5B:A9:70   2.4 GHz    72.2
# 2      192.168.1.32  MAC-IP Binding   F0:18:98:34:D4:40   2.4 GHz     130
# 3     192.168.1.151    Automatic IP   2E:21:5A:27:F7:86   2.4 GHz     130
# 4     192.168.1.160    Automatic IP   44:4F:8E:18:FD:28   2.4 GHz      52
#
#   Rx Rate Access time
# 0       -           -
# 1      11    00:24:12
# 2      24    00:24:34
# 3     130    00:12:58
# 4       1    00:11:39

# %%
# return data from filtered row

# %%
def getfilteredPandasDatafrome(df, columname, filtervalue):
    return df[df[columname] == filtervalue]

# %%
filterdf = getfilteredPandasDatafrome(df, "Interface", "2.4 GHz")
filterdf
# Out:
#    Internet access state                             Device Type  \
# 1  Allow Internet access                  Loading manufacturer..
# 2  Allow Internet access                              Apple Inc.
# 3  Allow Internet access                  Loading manufacturer..
# 4  Allow Internet access                                     WiZ
# 5  Allow Internet access                  Loading manufacturer..
# 6  Allow Internet access         dhcpcd-5.2.12:Linux-4.14.74:aar
# 7  Allow Internet access  Hangzhou BroadLink Technology Co. Ltd.
# 8  Allow Internet access                              Apple Inc.
# 9  Allow Internet access                              Apple Inc.
#
#             Client Name Client IP address       IP Method Clients MAC Address  \
# 1           BapuriWatch      192.168.1.20    Automatic IP   2C:7C:F2:5B:A9:70
# 2            YK-MacBook      192.168.1.32  MAC-IP Binding   F0:18:98:34:D4:40
# 3  Philips Wiz - Room 1     192.168.1.151    Automatic IP   2E:21:5A:27:F7:86
# 4  Philips Wiz - Room 2     192.168.1.160    Automatic IP   44:4F:8E:18:FD:28
# 5             Petkit_D4     192.168.1.175    Automatic IP   54:43:B2:04:D0:D4
# 6            robot-lulu     192.168.1.204    Automatic IP   88:12:AC:2B:E2:43
# 7    Osram Red - Room 1     192.168.1.227    Automatic IP   EC:0B:AE:A5:FC:7C
# 8             YK-PadPro     192.168.1.247    Automatic IP   78:7B:8A:59:D1:B4
# 9            YK-Pro-Max     192.168.1.252    Automatic IP   5C:87:30:B4:65:42
#
#   Interface Tx Rate Rx Rate Access time
# 1   2.4 GHz    72.2      11    00:24:12
# 2   2.4 GHz     130      24    00:24:34
# 3   2.4 GHz     130     130    00:12:58
# 4   2.4 GHz      52       1    00:11:39
# 5   2.4 GHz      65       6    00:08:05
# 6   2.4 GHz      65    72.2    00:24:43
# 7   2.4 GHz      65      52    00:24:25
# 8   2.4 GHz   144.4     130    00:24:39
# 9   2.4 GHz     195      24    00:23:44
